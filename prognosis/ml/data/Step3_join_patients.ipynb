# %%
import pandas as pd
import os

# %%
patients = pd.read_csv("../../..//data/mimic-4/patients.csv")

# %%
patients.shape
# Out:
# (364627, 6)

# %%
patients.head()
# Out:
#    subject_id gender  anchor_age  anchor_year anchor_year_group         dod
# 0    10000032      F          52         2180       2014 - 2016  2180-09-09
# 1    10000048      F          23         2126       2008 - 2010         NaN
# 2    10000058      F          33         2168       2020 - 2022         NaN
# 3    10000068      F          19         2160       2008 - 2010         NaN
# 4    10000084      M          72         2160       2017 - 2019  2161-02-13

# %%
patients.dtypes
# Out:
# subject_id            int64
# gender               object
# anchor_age            int64
# anchor_year           int64
# anchor_year_group    object
# dod                  object
# birth_year            int64
# dtype: object

# %%
patients["birth_year"] = patients["anchor_year"] - patients["anchor_age"]

# %%
trajectories = pd.read_csv('trajectories.csv').drop(columns=['Unnamed: 0'])
trajectories.shape
# Out:
# (5938215, 8)

# %%
trajectories.head()
# Out:
#    subject_id   hadm_id  seq_num icd10_code icd10_category  \
# 0    10000032  22595853        1       K766            K76
# 1    10000032  22595853        2       R188            R18
# 2    10000032  22595853        3       K740            K74
# 3    10000032  22595853        4      B1920            B19
# 4    10000032  22595853        5       J449            J44
#
#              admittime            dischtime deathtime
# 0  2180-05-06 22:23:00  2180-05-07 17:15:00       NaN
# 1  2180-05-06 22:23:00  2180-05-07 17:15:00       NaN
# 2  2180-05-06 22:23:00  2180-05-07 17:15:00       NaN
# 3  2180-05-06 22:23:00  2180-05-07 17:15:00       NaN
# 4  2180-05-06 22:23:00  2180-05-07 17:15:00       NaN

# %%
trajectories_patients = pd.merge(
    how="left",
    on="subject_id",
    left=trajectories,
    right=patients[["subject_id", "gender", "birth_year", "dod"]]
)

# %%
trajectories_patients.count()
# Out:
# subject_id        5938215
# hadm_id           5938215
# seq_num           5938215
# icd10_code        5938215
# icd10_category    5938215
# admittime         5938215
# dischtime         5938215
# deathtime          238549
# gender            5938215
# birth_year        5938215
# dod               2149226
# dtype: int64

# %%
trajectories_patients.to_csv("trajectories.csv", index=False)
